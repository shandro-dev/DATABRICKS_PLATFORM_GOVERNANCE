-- %%
select count(*) from data_governance.gold_cost.dim_cluster_nodes group by load_timestamp

-- %%
select count(*) from data_governance.gold_cost.dim_sku_pricing group by load_timestamp

-- %%
select count(*) from data_governance.gold_cost.fact_cost_usage group by load_timestamp

-- %%
select count(*) from data_governance.gold_access.dim_users group by load_timestamp

-- %%
select count(*) from data_governance.gold_access.fact_user_activity group by load_timestamp

-- %%
select count(*) from data_governance.gold_lineage.dim_jobs_metadata group by load_timestamp

-- %%
select count(*) from data_governance.gold_lineage.fact_lineage_column_flow group by load_timestamp

-- %%
select count(*) from data_governance.gold_lineage.fact_lineage_table_flow group by load_timestamp

-- %%
select count(*) from data_governance.gold_lineage.fact_query_info group by load_timestamp

-- %%
select count(*) from data_governance.gold_lineage.fact_job_performance group by load_timestamp

-- %%
select * FROM data_governance.gold_lineage.fact_lineage_table_flow

-- %%
SELECT *
    FROM data_governance.silver_lineage_analysis.lineage_table_level
