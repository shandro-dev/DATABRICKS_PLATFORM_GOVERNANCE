-- %%
select * from data_governance.gold_lineage.dim_jobs_metadata

-- %%
select * from data_governance.gold_lineage.fact_job_performance

-- %%
SELECT *
FROM data_governance.gold_lineage.fact_job_performance 
WHERE result_state != 'SUCCEEDED'
ORDER BY period_start_time ;

-- %%
drop table data_governance.silver_lineage_analysis.lineage_column_level
