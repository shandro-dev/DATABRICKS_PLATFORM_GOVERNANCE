-- %% [markdown]
-- BRONZE

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_access_management/ai_assistant_usage`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_access_management/audit_logs`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_access_management/table_permissions`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_cost_monitoring/billing_pricing`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_cost_monitoring/billing_usage_volume`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_cost_monitoring/cluster_node_type`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_cost_monitoring/job_run_timeline`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_lineage_analysis/lineage_column_level`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_lineage_analysis/lineage_table_level`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_lineage_analysis/query_history`

-- %%
TRUNCATE TABLE delta.`/Volumes/data_governance/bronze_lineage_analysis/workflow_metadata`

-- %% [markdown]
-- SILVER

-- %%
TRUNCATE TABLE data_governance.silver_access_management.assistant_usage

-- %%
TRUNCATE TABLE data_governance.silver_access_management.audit_logs

-- %%
TRUNCATE TABLE data_governance.silver_access_management.table_permissions

-- %%
TRUNCATE TABLE data_governance.silver_cost_monitoring.billing_pricing

-- %%
TRUNCATE TABLE data_governance.silver_cost_monitoring.billing_usage

-- %%
TRUNCATE TABLE data_governance.silver_cost_monitoring.cluster_node

-- %%
TRUNCATE TABLE data_governance.silver_cost_monitoring.job_run

-- %%
TRUNCATE TABLE data_governance.silver_lineage_analysis.lineage_column_level

-- %%
TRUNCATE TABLE data_governance.silver_lineage_analysis.lineage_query_history

-- %%
TRUNCATE TABLE data_governance.silver_lineage_analysis.lineage_table_level

-- %%
TRUNCATE TABLE data_governance.silver_lineage_analysis.lineage_workflow_metadata

-- %% [markdown]
-- GOLD

-- %%
TRUNCATE TABLE data_governance.gold_access.dim_table_permissions

-- %%
TRUNCATE TABLE data_governance.gold_access.dim_users

-- %%
TRUNCATE TABLE data_governance.gold_access.fact_assistant_uses

-- %%
TRUNCATE TABLE data_governance.gold_access.fact_user_access_activity

-- %%
TRUNCATE TABLE data_governance.gold_cost.dim_cluster_nodes

-- %%
TRUNCATE TABLE data_governance.gold_cost.dim_sku_pricing

-- %%
TRUNCATE TABLE data_governance.gold_cost.fact_cost_usage

-- %%
TRUNCATE TABLE data_governance.gold_lineage.dim_jobs_metadata

-- %%
TRUNCATE TABLE data_governance.gold_lineage.fact_job_performance

-- %%
TRUNCATE TABLE data_governance.gold_lineage.fact_lineage_column_flow

-- %%
TRUNCATE TABLE data_governance.gold_lineage.fact_lineage_table_flow

-- %%
TRUNCATE TABLE data_governance.gold_lineage.fact_query_info
