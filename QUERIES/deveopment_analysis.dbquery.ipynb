-- %%
select * from delta.`/Volumes/data_governance/access_management/ai_assistant_usage`;
select * from delta.`/Volumes/data_governance/access_management/audit_logs`;
--select * from delta.`/Volumes/data_governance/access_management/network_access`;
select * from delta.`/Volumes/data_governance/access_management/table_permissions`;

select * from delta.`/Volumes/data_governance/cost_monitoring/billing_pricing`;
select * from delta.`/Volumes/data_governance/cost_monitoring/billing_usage_volume`;
--select * from delta.`/Volumes/data_governance/cost_monitoring/cluster_details`;
select * from delta.`/Volumes/data_governance/cost_monitoring/cluster_node_type`;
select * from delta.`/Volumes/data_governance/cost_monitoring/job_run_timeline`;

select * from delta.`/Volumes/data_governance/lineage_analysis/lineage_column_level`;
select * from delta.`/Volumes/data_governance/lineage_analysis/lineage_table_level`;
select * from delta.`/Volumes/data_governance/lineage_analysis/query_history`;
select * from delta.`/Volumes/data_governance/lineage_analysis/workflow_metadata`;

select * from system.billing.usage;
select * from system.billing.list_prices;
select * from system.compute.clusters;
select * from system.compute.node_types;
select * from system.lakeflow.job_run_timeline;

select * from system.access.audit;
select * from system.information_schema.table_privileges;
select * from system.access.inbound_network;
select * from system.access.assistant_events;


select * from system.access.table_lineage;
select * from system.access.column_lineage;
select count(*) from system.query.history;
select * from system.lakeflow.jobs;
