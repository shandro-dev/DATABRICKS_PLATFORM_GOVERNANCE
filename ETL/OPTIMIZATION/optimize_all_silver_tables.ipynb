-- %%
optimize data_governance.silver_access_management.assistant_usage

-- %%
optimize data_governance.silver_access_management.audit_logs

-- %%
optimize data_governance.silver_access_management.table_permissions

-- %%
optimize data_governance.silver_cost_monitoring.billing_pricing

-- %%
optimize data_governance.silver_cost_monitoring.billing_usage

-- %%
optimize data_governance.silver_cost_monitoring.cluster_node

-- %%
optimize data_governance.silver_cost_monitoring.job_run

-- %%
optimize data_governance.silver_lineage_analysis.lineage_column_level

-- %%
optimize data_governance.silver_lineage_analysis.lineage_query_history

-- %%
optimize data_governance.silver_lineage_analysis.lineage_table_level

-- %%
optimize data_governance.silver_lineage_analysis.lineage_workflow_metadata
