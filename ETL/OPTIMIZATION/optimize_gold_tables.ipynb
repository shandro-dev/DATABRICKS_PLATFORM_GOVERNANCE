-- %%
optimize data_governance.gold_access.dim_users

-- %%
optimize data_governance.gold_access.fact_user_activity

-- %%
optimize data_governance.gold_cost.dim_cluster_nodes

-- %%
optimize data_governance.gold_cost.dim_sku_pricing

-- %%
optimize data_governance.gold_cost.fact_cost_usage

-- %%
optimize data_governance.gold_cost.fact_job_cost

-- %%
optimize data_governance.gold_lineage.dim_jobs_metadata

-- %%
optimize data_governance.gold_lineage.fact_column_lineage

-- %%
optimize data_governance.gold_lineage.fact_query_performance

-- %%
optimize data_governance.gold_lineage.fact_table_lineage
