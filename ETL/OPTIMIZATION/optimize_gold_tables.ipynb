-- %%
optimize data_governance.gold_access.dim_users

-- %%
optimize data_governance.gold_access.dim_table_permissions

-- %%
optimize data_governance.gold_access.fact_user_access_activity

-- %%
optimize data_governance.gold_cost.dim_cluster_nodes

-- %%
optimize data_governance.gold_cost.dim_sku_pricing

-- %%
optimize data_governance.gold_cost.fact_cost_usage

-- %%
optimize data_governance.gold_lineage.dim_jobs_metadata

-- %%
optimize data_governance.gold_lineage.fact_lineage_column_flow

-- %%
optimize data_governance.gold_lineage.fact_job_performance

-- %%
optimize data_governance.gold_lineage.fact_lineage_table_flow

-- %%
optimize data_governance.gold_lineage.fact_query_info

-- %%
optimize data_governance.gold_access.fact_user_access_activity
