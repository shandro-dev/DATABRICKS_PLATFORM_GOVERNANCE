-- %%
optimize delta.`/Volumes/data_governance/bronze_access_management/ai_assistant_usage`

-- %%
optimize delta.`/Volumes/data_governance/bronze_access_management/audit_logs`

-- %%
-- optimize delta.`/Volumes/data_governance/bronze_access_management/network_access`

-- %%
optimize delta.`/Volumes/data_governance/bronze_access_management/table_permissions`

-- %%
optimize delta.`/Volumes/data_governance/bronze_cost_monitoring/billing_pricing`

-- %%
-- optimize delta.`/Volumes/data_governance/bronze_cost_monitoring/cluster_details`

-- %%
optimize delta.`/Volumes/data_governance/bronze_cost_monitoring/cluster_node_type`

-- %%
optimize delta.`/Volumes/data_governance/bronze_cost_monitoring/job_run_timeline`

-- %%
optimize delta.`/Volumes/data_governance/bronze_lineage_analysis/lineage_column_level`

-- %%
optimize delta.`/Volumes/data_governance/bronze_lineage_analysis/lineage_table_level`

-- %%
optimize delta.`/Volumes/data_governance/bronze_lineage_analysis/query_history`

-- %%
optimize delta.`/Volumes/data_governance/bronze_lineage_analysis/query_history`

-- %%
optimize delta.`/Volumes/data_governance/bronze_lineage_analysis/workflow_metadata`
