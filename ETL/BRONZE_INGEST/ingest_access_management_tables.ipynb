# %% [markdown]
# CALL INGEST USER DEFINED FUNCTION

# %%
# %run ./UDF/udf_bronze_ingest

# %% [markdown]
# audit logs table

# %%
source_table="system.access.audit"
target_path="/Volumes/data_governance/bronze_access_management/audit_logs"
batch_size=250

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# table permissions table

# %%
source_table="system.information_schema.table_privileges"
target_path="/Volumes/data_governance/bronze_access_management/table_permissions"
batch_size=50

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# network access table

# %%
source_table="system.access.inbound_network"
target_path="/Volumes/data_governance/bronze_access_management/network_access"
batch_size=50

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# ai-assistance usage table

# %%
source_table="system.access.assistant_events"
target_path="/Volumes/data_governance/bronze_access_management/ai_assistant_usage"
batch_size=200

ingest_batch(source_table,target_path,batch_size)
