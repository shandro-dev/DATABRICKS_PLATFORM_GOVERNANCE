# %% [markdown]
# #####CALL INGEST USER DEFINED FUNCTION

# %%
# %run ./UDF/udf_bronze_ingest

# %% [markdown]
# billing usage table

# %%
source_table="system.billing.usage"
target_path="/Volumes/data_governance/cost_monitoring/billing_usage_volume"
batch_size=500

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# billing list_prices

# %%
source_table="system.billing.list_prices"
target_path="/Volumes/data_governance/cost_monitoring/billing_pricing"
batch_size=50

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# cluster details

# %%
source_table="system.compute.clusters"
target_path="/Volumes/data_governance/cost_monitoring/cluster_details"
batch_size=100

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# node_types

# %%
source_table="system.compute.node_types"
target_path="/Volumes/data_governance/cost_monitoring/cluster_node_type"
batch_size=100

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# job_run_timeline

# %%
source_table="system.lakeflow.job_run_timeline"
target_path="/Volumes/data_governance/cost_monitoring/job_run_timeline"
batch_size=100

ingest_batch(source_table,target_path,batch_size)
