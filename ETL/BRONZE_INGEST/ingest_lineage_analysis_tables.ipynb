# %% [markdown]
# CALL INGEST USER DEFINED FUNCTION

# %%
# %run ./UDF/udf_bronze_ingest

# %% [markdown]
# lineage table level data

# %%
source_table="system.access.table_lineage"
target_path="/Volumes/data_governance/bronze_lineage_analysis/lineage_table_level"
batch_size=100

ingest_batch(source_table,target_path,batch_size)

# %%
spark.read.table("system.access.table_lineage").printSchema()

# %% [markdown]
# lineage column level data

# %%
source_table="system.access.column_lineage"
target_path="/Volumes/data_governance/bronze_lineage_analysis/lineage_column_level"
batch_size=500

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# query history table

# %%
source_table="system.query.history"
target_path="/Volumes/data_governance/bronze_lineage_analysis/query_history"
batch_size=100

ingest_batch(source_table,target_path,batch_size)

# %% [markdown]
# workflow - jobs pipelines/metadata table

# %%
source_table="system.lakeflow.jobs"
target_path="/Volumes/data_governance/bronze_lineage_analysis/workflow_metadata"
batch_size=100

ingest_batch(source_table,target_path,batch_size)
